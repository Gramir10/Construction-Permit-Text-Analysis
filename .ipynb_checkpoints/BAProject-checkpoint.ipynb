# %%
#libraries
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.figure_factory as ff

# %%
data_HP = "https://data.baltimorecity.gov/resource/fesm-tgxf.json"
df_HP = pd.read_json(data_HP)
df_HP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   permitid                     1000 non-null   object
#  1   casenum                      1000 non-null   object
#  2   block                        1000 non-null   object
#  3   lot                          1000 non-null   object
#  4   propertyaddress              1000 non-null   object
#  5   permitnum                    1000 non-null   object
#  6   dateissue                    1000 non-null   object
#  7   permitdescription            1000 non-null   object
#  8   cost_est                     766 non-null    float64
#  9   dateexpire                   925 non-null    object
#  10  prop_use                     1000 non-null   object
#  11  existing_use                 1000 non-null   object
#  12  neighborhood                 930 non-null    object
#  13  policedistrict               925 non-null    object
#  14  councildistrict              925 non-null    float64
#  15  location                     1000 non-null   object
#  16  :@computed_region_5kre_ccpb  977 non-null    float64
#  17  :@computed_region_gwq4_fjxs  977 non-null    float64
#  18  :@computed_region_s6p5_2pgr  981 non-null    float64
# dtypes: float64(5), object(14)
# memory usage: 148.6+ KB

# %%
df_HP.head()
# Out:
#              permitid        casenum block  lot      propertyaddress  \
# 0  20190807134234483B  COM2019-02783  4868  002      5407 ROLAND AVE
# 1  20200318090350660B  USE2020-51401  3065  014         3400 ALTO RD
# 2  20200211153150203B  USE2020-50665  3653  061  2918 HUNTINGDON AVE
# 3  20200420123851710B  USE2020-51760  2848  014  2901 MOUNT HOLLY ST
# 4  20200420103033843B  USE2020-51763  1789  072      504 S GLOVER ST
#
#        permitnum                dateissue  \
# 0  COM2019-02783  2020-09-20T00:00:00.000
# 1  USE2020-51401  2020-04-22T16:00:17.000
# 2  USE2020-50665  2020-04-22T14:30:07.000
# 3  USE2020-51760  2020-04-22T13:00:08.000
# 4  USE2020-51763  2020-04-22T13:00:08.000
#
#                                    permitdescription  cost_est  \
# 0               fire alarm as per plans as per code.   10000.0
# 1                            single family occupancy       NaN
# 2                   use as a single-family dwelling.       NaN
# 3  use premises for a single family detached dwel...       NaN
# 4                   use as a single-family dwelling.       NaN
#
#                 dateexpire prop_use existing_use     neighborhood  \
# 0  2020-03-20T00:00:00.000     2-04         2-04        WYNDHURST
# 1                      NaN     1-09         1-09  HANLON-LONGWOOD
# 2                      NaN     1-08         1-08        REMINGTON
# 3                      NaN     1-05         1-05    WINDSOR HILLS
# 4                      NaN     1-08         1-08           CANTON
#
#   policedistrict  councildistrict  \
# 0       Northern              6.0
# 1   Northwestern              7.0
# 2       Northern             12.0
# 3   Northwestern              6.0
# 4   Southeastern              1.0
#
#                                             location  \
# 0  {'latitude': '39.361681', 'longitude': '-76.63...
# 1  {'latitude': '39.317301', 'longitude': '-76.67...
# 2  {'latitude': '39.321969', 'longitude': '-76.62...
# 3  {'latitude': '39.320043', 'longitude': '-76.68...
# 4  {'latitude': '39.285742', 'longitude': '-76.57...
#
#    :@computed_region_5kre_ccpb  :@computed_region_gwq4_fjxs  \
# 0                        265.0                        254.0
# 1                        103.0                         47.0
# 2                        209.0                         13.0
# 3                        260.0                         49.0
# 4                         30.0                        114.0
#
#    :@computed_region_s6p5_2pgr
# 0                      14004.0
# 1                      27297.0
# 2                      14006.0
# 3                      27297.0
# 4                      27935.0

# %%
#Removing Rows that have Null Values
df_HP = df_HP[df_HP["cost_est"].notnull()]
df_HP = df_HP[df_HP["neighborhood"].notnull()]
df_HP = df_HP[df_HP["policedistrict"].notnull()]
df_HP = df_HP[df_HP["councildistrict"].notnull()]
# rename corrupted column names
df_HP = df_HP.rename(columns = {":@computed_region_5kre_ccpb": "2010 Census Neighborhoods",
                                ":@computed_region_gwq4_fjxs": "2010 Census Wards Precincts",
                                ":@computed_region_s6p5_2pgr": "Zip Codes"})

# %%
df_HP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   permitid                     699 non-null    object
#  1   casenum                      699 non-null    object
#  2   block                        699 non-null    object
#  3   lot                          699 non-null    object
#  4   propertyaddress              699 non-null    object
#  5   permitnum                    699 non-null    object
#  6   dateissue                    699 non-null    object
#  7   permitdescription            699 non-null    object
#  8   cost_est                     699 non-null    float64
#  9   dateexpire                   699 non-null    object
#  10  prop_use                     699 non-null    object
#  11  existing_use                 699 non-null    object
#  12  neighborhood                 699 non-null    object
#  13  policedistrict               699 non-null    object
#  14  councildistrict              699 non-null    float64
#  15  location                     699 non-null    object
#  16  2010 Census Neighborhoods    694 non-null    float64
#  17  2010 Census Wards Precincts  694 non-null    float64
#  18  Zip Codes                    696 non-null    float64
# dtypes: float64(5), object(14)
# memory usage: 109.2+ KB
